# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Using cached https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz
# Building wheels for collected packages: PyPDF2
#   Running setup.py bdist_wheel for PyPDF2: started
#   Running setup.py bdist_wheel for PyPDF2: finished with status 'done'
#   Stored in directory: C:\Users\shira\AppData\Local\pip\Cache\wheels\53\84\19\35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
# pdf_merger.py
 
import glob
from PyPDF2 import PdfFileWriter, PdfFileReader
 
def merger(output_path, input_paths):
    pdf_writer = PdfFileWriter()
 \\
    for path in input_paths:
        pdf_reader = PdfFileReader(path)
        for page in range(pdf_reader.getNumPages()):
            pdf_writer.addPage(pdf_reader.getPage(page))
 
    with open(output_path, 'wb') as fh:
        pdf_writer.write(fh)
 
 
if __name__ == '__main__':
    paths = glob.glob('WEF_*.pdf')
    paths.sort()
    merger('pdf_merger.pdf', paths)

# %%
#Step 1- convert into text

#Use TIKA Lib for merging file
import sys
from tika import parser

parsed = parser.from_file('pdf_merger.pdf')

#Pass output in text file
sys.stdout = open('o.txt','wt',encoding='utf-8')
print(parsed ["content"])
# Out:
# 2019-02-19 18:13:07,507 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar to C:\Users\shira\AppData\Local\Temp\tika-server.jar.
# 2019-02-19 18:13:44,286 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar.md5 to C:\Users\shira\AppData\Local\Temp\tika-server.jar.md5.
# 2019-02-19 18:13:44,860 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...

# %%
#Step2 - remove special characters from text file

#Used regular expression
import re

string = open('o.txt', encoding= 'utf-8').read()
new_str = re.sub('[^a-zA-Z0-9\n\.]', ' ', string)
open('oupdated.txt','w').write(new_str)
# Out:
# 901513

# %%
#Step 3- #Cleanning data 
file__1 = open('rstopwords.txt', 'r')
file_2 = open('clean.txt', 'w')
file_1_cont = file1.readlines()

#remove stopwords using stopword file

for line in file1_cont:
    line.replace('.', ' ')
    file2.write(line)remove stopwords using given file of stopwords
stoplist = []
file_1 = open('l.txt','r')
file_2 = open('stopwords.txt','r')
file_3 = open('cleanedv1.txt','a')

#Add the words 
for line in file2:
    w = line.split()
    for word in w:
        stoplist.append(word)

for line in file1:
    w = line.split()
    for word in w:
        if word in stoplist: continue
        else: 
            file3.write(word)
            file3.write(' ')

#end 
file1.close()
file2.close()
file3.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-935976aacc86> in <module>
#       2 file__1 = open('oupdated.txt', 'r')
#       3 file_2 = open('clean.txt', 'w')
# ----> 4 file_1_cont = file1.readlines()
#       5
#       6 #remove stopwords using stopword file
#
# NameError: name 'file1' is not defined

# %%
#Cleanning dots 
file1 = open('rstopwords.txt', 'r')
file2 = open('clean.txt', 'w')
file1_cont = file1.readlines()
for line in file1_cont:
    line.replace('.', ' ')
    file2.write(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-56-a6c7dc2711f7> in <module>
#       1 #Cleanning dots
# ----> 2 file1 = open('rstopwords.txt', 'r')
#       3 file2 = open('clean.txt', 'w')
#       4 file1_cont = file1.readlines()
#       5 for line in file1_cont:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rstopwords.txt'

# %%
#Lower the cases
with open('rstopwords.txt', 'r') as fileinput:
   for line in fileinput:
       line = line.lower()#Remove all the unwanted words 
#cleanning word using NLTK
import io 
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

#word_tokenize accepts a string as an input, not a file. 
stop_words = set(stopwords.words('english')) 
file1 = open("cleanedv1.txt") 
line = file1.read()
print("Cleaned executed")

# Use this to read file content as a stream: 
words = line.split() 
for r in words: 
	if not r in stop_words: 
		appendFile = open('filteredtext.txt','a') 
		appendFile.write(" "+r) 
		appendFile.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-e5be2bbaa621> in <module>
#       1 #Lower the cases
# ----> 2 with open('rstopwords.txt', 'r') as fileinput:
#       3    for line in fileinput:
#       4        line = line.lower()#Remove all the unwanted words
#       5 #cleanning word using NLTK
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rstopwords.txt'

# %%
# import nlp libraries
import string
import collections
import nltk
from nltk.corpus import stopwords
from nltk.util import ngrams
import nltk, re, string, collections
from nltk.util import ngrams # function for making ngrams

# set nlp variables
english_stops = stopwords.words('english')
lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
#Convert Text file into list
with open("/Users/shira/OneDrive/Desktop/ML/Case Study1/filteredtext.txt", "r", encoding='utf-8') as file:
    text = file.read()
    tokens = nltk.word_tokenize(text)

# %%
#create function to clean text , Lowercases, takes out punct and short strings
def cleanning_tokens(tokens):
    return [token.lower() for token in tokens if (token not in string.punctuation) and 
                   (token.lower() not in english_stops) and len(token) > 2]

#create function to Lemmatize like remove plurals(play, plays)- it will save- play
def lemmatize(tokens): 
    return [lemmatizer.lemmatize(token) for token in tokens]

# %%
#Clean words
clean = cleanning_tokens(tokens)
#print(clean)
lem = lemmatize(clean)

# %%
def count_ngrams(tokens,n):
    n_grams = ngrams(tokens, n)
    ngram_freq = collections.Counter(n_grams)
    ngram_freq = ngram_freq.most_common()
    print("Count ngrams executed", ngram_freq)
    return ngram_freq

def ngram_to_dict(ngram_freq):
    l = []
    for t in ngram_freq:
        l.append((' '.join(t[0]),t[1]))
    print("Ngram to dict completed", l)
    return dict(l)

# %%
# count word and ngram frequency
word_freq = count_ngrams(lem, 1)
bigram_freq = count_ngrams(lem, 2)
#trigram_freq = counting_ngrams(lemmi, 3)
#ngramFrequency = bigram_freq + trigram_freq

# %%
word_freq
# Out:
# [(('customer',), 2004),
#  (('financial',), 1878),
#  (('service',), 1328),
#  (('bank',), 1296),
#  (('market',), 1264),
#  (('identity',), 1192),
#  (('platform',), 1168),
#  (('institution',), 1148),
#  (('payment',), 1132),
#  (('data',), 1080),
#  (('risk',), 1060),
#  (('product',), 954),
#  (('system',), 906),
#  (('process',), 848),
#  (('investor',), 838),
#  (('digital',), 824),
#  (('key',), 742),
#  (('investment',), 740),
#  (('transaction',), 738),
#  (('traditional',), 738),
#  (('user',), 732),
#  (('insurance',), 684),
#  (('alternative',), 644),
#  (('asset',), 578),
#  (('economic',), 558),
#  (('technology',), 554),
#  (('uncertainty',), 554),
#  (('forum',), 548),
#  (('time',), 546),
#  (('capital',), 538),
#  (('future',), 532),
#  (('business',), 532),
#  (('cost',), 532),
#  (('provider',), 532),
#  (('implication',), 524),
#  (('insurer',), 524),
#  (('access',), 496),
#  (('regulator',), 488),
#  (('scenario',), 488),
#  (('solution',), 478),
#  (('incumbent',), 476),
#  (('individual',), 468),
#  (('lending',), 468),
#  (('management',), 466),
#  (('state',), 464),
#  (('finding',), 458),
#  (('based',), 454),
#  (('model',), 452),
#  (('opportunity',), 442),
#  (('entity',), 424),
#  (('provide',), 422),
#  (('potential',), 412),
#  (('intermediary',), 402),
#  (('regulatory',), 400),
#  (('dlt',), 400),
#  (('world',), 384),
#  (('trade',), 374),
#  (('large',), 372),
#  (('case',), 366),
#  (('attribute',), 366),
#  (('innovation',), 358),
#  (('high',), 346),
#  (('transfer',), 342),
#  (('conclusion',), 340),
#  (('network',), 338),
#  (('card',), 336),
#  (('ecosystem',), 334),
#  (('global',), 332),
#  (('equity',), 332),
#  (('industry',), 328),
#  (('loan',), 320),
#  (('fis',), 318),
#  (('credit',), 314),
#  (('smart',), 312),
#  (('contract',), 308),
#  (('infrastructure',), 304),
#  (('benefit',), 298),
#  (('trading',), 298),
#  (('source',), 296),
#  (('real',), 294),
#  (('statesintroduction',), 294),
#  (('party',), 290),
#  (('funding',), 286),
#  (('automated',), 284),
#  (('firm',), 282),
#  (('offer',), 280),
#  (('banking',), 278),
#  (('online',), 278),
#  (('account',), 276),
#  (('deloitte',), 272),
#  (('role',), 268),
#  (('company',), 268),
#  (('fund',), 262),
#  (('scale',), 256),
#  (('capability',), 254),
#  (('ability',), 254),
#  (('mobile',), 254),
#  (('project',), 252),
#  (('increased',), 252),
#  (('strategy',), 250),
#  (('experience',), 248),
#  (('activity',), 248),
#  (('change',), 246),
#  (('current',), 246),
#  (('lender',), 238),
#  (('impact',), 236),
#  (('wealth',), 234),
#  (('crowdfunding',), 234),
#  (('level',), 232),
#  (('channel',), 232),
#  (('distributed',), 232),
#  (('low',), 232),
#  (('condition',), 232),
#  (('number',), 230),
#  (('lead',), 228),
#  (('core',), 228),
#  (('claim',), 228),
#  (('focus',), 226),
#  (('critical',), 224),
#  (('increase',), 224),
#  (('group',), 220),
#  (('standard',), 220),
#  (('scheme',), 220),
#  (('development',), 218),
#  (('allow',), 216),
#  (('shift',), 212),
#  (('offering',), 212),
#  (('partnership',), 210),
#  (('money',), 210),
#  (('loss',), 206),
#  (('distribution',), 206),
#  (('merchant',), 204),
#  (('control',), 204),
#  (('additional',), 200),
#  (('manager',), 198),
#  (('set',), 198),
#  (('compliance',), 194),
#  (('regulation',), 192),
#  (('point',), 192),
#  (('retrieved',), 192),
#  (('http',), 192),
#  (('summary',), 190),
#  (('gain',), 188),
#  (('settlement',), 188),
#  (('chain',), 186),
#  (('fee',), 186),
#  (('increasing',), 184),
#  (('idp',), 184),
#  (('retail',), 182),
#  (('share',), 182),
#  (('create',), 180),
#  (('underwriting',), 180),
#  (('private',), 178),
#  (('improve',), 178),
#  (('relationship',), 176),
#  (('lower',), 176),
#  (('ledger',), 174),
#  (('limited',), 172),
#  (('government',), 172),
#  (('directly',), 172),
#  (('study',), 172),
#  (('partner',), 170),
#  (('fintechs',), 170),
#  (('emerging',), 170),
#  (('competitive',), 170),
#  (('existing',), 170),
#  (('pressure',), 170),
#  (('connected',), 170),
#  (('life',), 170),
#  (('required',), 170),
#  (('security',), 168),
#  (('member',), 166),
#  (('report',), 164),
#  (('stakeholder',), 164),
#  (('interest',), 164),
#  (('legal',), 162),
#  (('growth',), 162),
#  (('faster',), 160),
#  (('question',), 158),
#  (('view',), 158),
#  (('improved',), 158),
#  (('today',), 156),
#  (('single',), 156),
#  (('support',), 154),
#  (('challenge',), 154),
#  (('exchange',), 152),
#  (('approach',), 150),
#  (('enable',), 150),
#  (('buyer',), 150),
#  (('associated',), 148),
#  (('player',), 146),
#  (('competition',), 146),
#  (('bond',), 146),
#  (('head',), 144),
#  (('machine',), 144),
#  (('efficiency',), 144),
#  (('venture',), 144),
#  (('seller',), 144),
#  (('analysis',), 142),
#  (('mass',), 142),
#  (('return',), 142),
#  (('tech',), 142),
#  (('adoption',), 140),
#  (('personal',), 140),
#  (('order',), 138),
#  (('reduce',), 138),
#  (('third',), 138),
#  (('increasingly',), 136),
#  (('providing',), 136),
#  (('borrower',), 136),
#  (('ceo',), 136),
#  (('client',), 134),
#  (('open',), 134),
#  (('demand',), 134),
#  (('small',), 132),
#  (('start',), 132),
#  (('supporting',), 132),
#  (('raising',), 132),
#  (('reduced',), 132),
#  (('proxy',), 132),
#  (('expert',), 130),
#  (('making',), 130),
#  (('consumer',), 130),
#  (('transparency',), 130),
#  (('implementation',), 130),
#  (('custodian',), 130),
#  (('participant',), 128),
#  (('multiple',), 128),
#  (('example',), 128),
#  (('tool',), 128),
#  (('trust',), 128),
#  (('term',), 126),
#  (('requirement',), 126),
#  (('rise',), 124),
#  (('choice',), 124),
#  (('evidence',), 124),
#  (('marketplace',), 124),
#  (('result',), 124),
#  (('post',), 124),
#  (('authentication',), 124),
#  (('counterparty',), 124),
#  (('decision',), 122),
#  (('director',), 122),
#  (('external',), 122),
#  (('deposit',), 122),
#  (('niche',), 122),
#  (('executive',), 120),
#  (('ownership',), 120),
#  (('price',), 120),
#  (('execution',), 120),
#  (('higher',), 118),
#  (('develop',), 118),
#  (('revenue',), 118),
#  (('lack',), 118),
#  (('trusted',), 118),
#  (('public',), 116),
#  (('landscape',), 116),
#  (('function',), 116),
#  (('advantage',), 116),
#  (('driven',), 116),
#  (('record',), 116),
#  (('structure',), 114),
#  (('saving',), 114),
#  (('require',), 114),
#  (('counterparties',), 114),
#  (('rps',), 114),
#  (('team',), 112),
#  (('entrant',), 112),
#  (('connection',), 112),
#  (('continue',), 112),
#  (('policy',), 112),
#  (('complete',), 112),
#  (('manual',), 112),
#  (('better',), 110),
#  (('device',), 110),
#  (('smaller',), 110),
#  (('statement',), 110),
#  (('sector',), 108),
#  (('advice',), 108),
#  (('well',), 108),
#  (('detail',), 108),
#  (('enabling',), 108),
#  (('human',), 108),
#  (('margin',), 108),
#  (('visibility',), 108),
#  (('specific',), 108),
#  (('economy',), 108),
#  (('best',), 108),
#  (('rate',), 106),
#  (('good',), 106),
#  (('social',), 106),
#  (('creating',), 104),
#  (('institutional',), 104),
#  (('chief',), 104),
#  (('build',), 104),
#  (('including',), 104),
#  (('ensure',), 104),
#  (('processing',), 104),
#  (('facilitate',), 104),
#  (('force',), 102),
#  (('liability',), 102),
#  (('cross',), 102),
#  (('country',), 102),
#  (('cash',), 102),
#  (('central',), 102),
#  (('finance',), 102),
#  (('stage',), 102),
#  (('liquidity',), 102),
#  (('rail',), 100),
#  (('robo',), 100),
#  (('drive',), 100),
#  (('event',), 100),
#  (('physical',), 100),
#  (('flow',), 98),
#  (('continued',), 98),
#  (('early',), 98),
#  (('application',), 98),
#  (('established',), 96),
#  (('automation',), 96),
#  (('compete',), 96),
#  (('environment',), 96),
#  (('currency',), 96),
#  (('net',), 96),
#  (('deliver',), 96),
#  (('organization',), 94),
#  (('direct',), 94),
#  (('effort',), 94),
#  (('leading',), 94),
#  (('commercial',), 94),
#  (('corporation',), 94),
#  (('base',), 92),
#  (('move',), 92),
#  (('sender',), 92),
#  (('disruptive',), 90),
#  (('driving',), 90),
#  (('year',), 90),
#  (('allows',), 90),
#  (('error',), 90),
#  (('major',), 90),
#  (('connectivity',), 90),
#  (('history',), 90),
#  (('reducing',), 90),
#  (('rehypothecation',), 90),
#  (('matter',), 88),
#  (('work',), 88),
#  (('three',), 88),
#  (('characteristic',), 88),
#  (('profit',), 88),
#  (('advisor',), 88),
#  (('wallet',), 88),
#  (('leveraging',), 88),
#  (('diligence',), 88),
#  (('coco',), 88),
#  (('disruption',), 86),
#  (('subject',), 86),
#  (('officer',), 86),
#  (('allowing',), 86),
#  (('delivery',), 86),
#  (('behaviour',), 86),
#  (('shared',), 86),
#  (('shifting',), 86),
#  (('local',), 86),
#  (('description',), 84),
#  (('face',), 84),
#  (('leverage',), 84),
#  (('review',), 84),
#  (('area',), 84),
#  (('usage',), 84),
#  (('option',), 84),
#  (('voting',), 84),
#  (('form',), 82),
#  (('segment',), 82),
#  (('manage',), 82),
#  (('creation',), 82),
#  (('audit',), 82),
#  (('limit',), 82),
#  (('externalisation',), 82),
#  (('fintech',), 80),
#  (('leader',), 80),
#  (('pay',), 80),
#  (('sharing',), 80),
#  (('collection',), 80),
#  (('sophisticated',), 80),
#  (('framework',), 78),
#  (('growing',), 78),
#  (('canada',), 78),
#  (('developed',), 78),
#  (('loyalty',), 78),
#  (('dfindings',), 78),
#  (('issue',), 76),
#  (('successful',), 76),
#  (('kyc',), 76),
#  (('store',), 76),
#  (('help',), 76),
#  (('fraud',), 76),
#  (('trend',), 76),
#  (('stored',), 76),
#  (('highly',), 76),
#  (('sell',), 76),
#  (('decentralised',), 76),
#  (('international',), 74),
#  (('action',), 74),
#  (('corporate',), 74),
#  (('outcome',), 74),
#  (('building',), 74),
#  (('position',), 74),
#  (('purchase',), 74),
#  (('clearing',), 74),
#  (('coverage',), 74),
#  (('operation',), 74),
#  (('currently',), 74),
#  (('servicing',), 74),
#  (('adjudication',), 72),
#  (('monitor',), 72),
#  (('secure',), 72),
#  (('advisory',), 72),
#  (('greater',), 72),
#  (('strong',), 72),
#  (('volume',), 72),
#  (('quantitative',), 72),
#  (('agreement',), 72),
#  (('invest',), 72),
#  (('profile',), 72),
#  (('billion',), 72),
#  (('preference',), 72),
#  (('broker',), 72),
#  (('vote',), 72),
#  (('assessment',), 70),
#  (('professional',), 70),
#  (('managing',), 70),
#  (('deep',), 70),
#  (('choose',), 70),
#  (('receive',), 70),
#  (('legacy',), 70),
#  (('larger',), 70),
#  (('decrease',), 70),
#  (('track',), 70),
#  (('meet',), 70),
#  (('smarter',), 70),
#  (('class',), 70),
#  (('seed',), 70),
#  (('collateral',), 70),
#  (('determine',), 68),
#  (('protocol',), 68),
#  (('broader',), 68),
#  (('evolve',), 68),
#  (('easily',), 68),
#  (('narrative',), 68),
#  (('difficult',), 68),
#  (('factor',), 68),
#  (('issuer',), 68),
#  (('consolidation',), 68),
#  (('virtual',), 68),
#  (('secondary',), 68),
#  (('transparent',), 68),
#  (('tax',), 66),
#  (('document',), 66),
#  (('improvement',), 66),
#  (('exist',), 66),
#  (('expand',), 66),
#  (('analytics',), 66),
#  (('pain',), 66),
#  (('initiate',), 66),
#  (('participate',), 66),
#  (('worth',), 66),
#  (('provisioning',), 66),
#  (('trader',), 66),
#  (('provided',), 64),
#  (('changing',), 64),
#  (('effective',), 64),
#  (('size',), 64),
#  (('hold',), 64),
#  (('news',), 64),
#  (('response',), 64),
#  (('line',), 64),
#  (('accurate',), 64),
#  (('operational',), 64),
#  (('trigger',), 64),
#  (('algorithmic',), 64),
#  (('correspondent',), 64),
#  (('rule',), 62),
#  (('understanding',), 62),
#  (('total',), 62),
#  (('entry',), 62),
#  (('day',), 62),
#  (('purpose',), 62),
#  (('method',), 62),
#  (('improving',), 62),
#  (('full',), 62),
#  (('request',), 62),
#  (('accuracy',), 62),
#  (('citizen',), 62),
#  (('involved',), 60),
#  (('acknowledgement',), 60),
#  (('operating',), 60),
#  (('path',), 60),
#  (('understand',), 60),
#  (('blockchain',), 60),
#  (('overview',), 60),
#  (('national',), 60),
#  (('range',), 60),
#  (('origination',), 60),
#  (('interaction',), 60),
#  (('buy',), 60),
#  (('problem',), 60),
#  (('introduction',), 60),
#  (('profitability',), 60),
#  (('paint',), 60),
#  (('health',), 60),
#  (('monitoring',), 60),
#  (('privacy',), 60),
#  (('streamlined',), 60),
#  (('enables',), 60),
#  (('arranger',), 60),
#  (('working',), 58),
#  (('office',), 58),
#  (('portfolio',), 58),
#  (('focused',), 58),
#  (('power',), 58),
#  (('long',), 58),
#  (('grow',), 58),
#  (('sale',), 58),
#  (('effectively',), 58),
#  (('protection',), 58),
#  (('governance',), 58),
#  (('standardized',), 58),
#  (('adopt',), 58),
#  (('valuable',), 58),
#  (('requires',), 58),
#  (('primary',), 58),
#  (('relying',), 58),
#  (('syndicate',), 58),
#  (('community',), 56),
#  (('basis',), 56),
#  (('swift',), 56),
#  (('relevant',), 56),
#  (('innovative',), 56),
#  (('internal',), 56),
#  (('advanced',), 56),
#  (('evolution',), 56),
#  (('balance',), 56),
#  (('designed',), 56),
#  (('sufficient',), 56),
#  (('beneficiary',), 56),
#  (('calculation',), 56),
#  (('serve',), 54),
#  (('driver',), 54),
#  (('target',), 54),
#  (('seamless',), 54),
#  (('remain',), 54),
#  (('medium',), 54),
#  (('selection',), 54),
#  (('affluent',), 54),
#  (('resource',), 54),
#  (('operator',), 54),
#  (('financing',), 54),
#  (('electronic',), 54),
#  (('ratio',), 54),
#  (('insight',), 52),
#  (('llp',), 52),
#  (('morgan',), 52),
#  (('rapidly',), 52),
#  (('dive',), 52),
#  (('rapid',), 52),
#  (('success',), 52),
#  (('barrier',), 52),
#  (('manufacturer',), 52),
#  (('automate',), 52),
#  (('differentiate',), 52),
#  (('aggregation',), 52),
#  (('reporting',), 52),
#  (('match',), 52),
#  (('cloud',), 52),
#  (('built',), 52),
#  (('sign',), 52),
#  (('common',), 52),
#  (('big',), 52),
#  (('cashless',), 52),
#  (('frequency',), 52),
#  (('field',), 52),
#  (('disaggregation',), 52),
#  (('pricing',), 52),
#  (('premium',), 52),
#  (('integration',), 52),
#  (('perform',), 52),
#  (('supply',), 52),
#  (('mechanism',), 52),
#  (('transform',), 52),
#  (('interview',), 50),
#  (('united',), 50),
#  (('responsible',), 50),
#  (('person',), 50),
#  (('senior',), 50),
#  (('launched',), 50),
#  (('context',), 50),
#  (('enabled',), 50),
#  (('expectation',), 50),
#  (('archetype',), 50),
#  (('utility',), 50),
#  (('accessible',), 50),
#  (('distributor',), 50),
#  (('retailer',), 50),
#  (('find',), 50),
#  (('amount',), 50),
#  (('play',), 50),
#  (('proposition',), 50),
#  (('jurisdiction',), 50),
#  (('top',), 50),
#  (('income',), 50),
#  (('meant',), 50),
#  (('remaining',), 50),
#  (('represent',), 50),
#  (('performance',), 50),
#  (('default',), 50),
#  (('defined',), 50),
#  (('transferred',), 50),
#  (('syndicated',), 50),
#  (('workshop',), 48),
#  (('expertise',), 48),
#  (('capacity',), 48),
#  (('location',), 48),
#  (('side',), 48),
#  (('identify',), 48),
#  (('brand',), 48),
#  (('engagement',), 48),
#  (('house',), 48),
#  (('limiting',), 48),
#  (('pattern',), 48),
#  (('creates',), 48),
#  (('programme',), 48),
#  (('popularity',), 48),
#  (('agent',), 48),
#  (('algorithm',), 48),
#  (('quality',), 48),
#  (('saver',), 48),
#  (('efficient',), 48),
#  (('agency',), 48),
#  (('executed',), 48),
#  (('multi',), 48),
#  (('founder',), 48),
#  (('importer',), 48),
#  (('insuree',), 48),
#  (('place',), 46),
#  (('interact',), 46),
#  (('add',), 46),
#  (('amazon',), 46),
#  (('reference',), 46),
#  (('functionality',), 46),
#  (('degree',), 46),
#  (('type',), 46),
#  (('concern',), 46),
#  (('test',), 46),
#  (('population',), 46),
#  (('flexible',), 46),
#  (('body',), 46),
#  (('telematics',), 46),
#  (('sophistication',), 46),
#  (('knowledge',), 46),
#  (('complex',), 46),
#  (('ensuring',), 46),
#  (('commoditised',), 46),
#  (('import',), 46),
#  (('detailed',), 44),
#  (('reuters',), 44),
#  (('john',), 44),
#  (('crisis',), 44),
#  (('way',), 44),
#  (('innovator',), 44),
#  (('technological',), 44),
#  (('engage',), 44),
#  (('seeking',), 44),
#  (('wide',), 44),
#  (('peer',), 44),
#  (('collect',), 44),
#  (('manufacturing',), 44),
#  (('design',), 44),
#  (('occur',), 44),
#  (('forbes',), 44),
#  (('playing',), 44),
#  (('comprehensive',), 44),
#  (('lifestyle',), 44),
#  (('connect',), 44),
#  (('insurtechs',), 44),
#  (('exposure',), 44),
#  (('vehicle',), 44),
#  (('integrated',), 44),
#  (('eliminating',), 44),
#  (('natural',), 44),
#  (('interoperability',), 44),
#  (('proof',), 44),
#  (('topic',), 44),
#  (('letter',), 44),
#  (('export',), 44),
#  (('auditor',), 44),
#  (('series',), 42),
#  (('collaboration',), 42),
#  (('jesse',), 42),
#  (('mcwaters',), 42),
#  (('org',), 42),
#  (('property',), 42),
#  (('thomson',), 42),
#  (('stock',), 42),
#  (('establish',), 42),
#  (('pool',), 42),
#  (('dependent',), 42),
#  (('streamline',), 42),
#  (('connecting',), 42),
#  (('reach',), 42),
#  (('apps',), 42),
#  (('seek',), 42),
#  (('investing',), 42),
#  (('emerged',), 42),
#  (('raise',), 42),
#  (('depending',), 42),
#  (('reward',), 42),
#  (('lose',), 42),
#  (('hedge',), 42),
#  (('participation',), 42),
#  (('centralized',), 42),
#  (('consent',), 42),
#  (('registry',), 42),
#  (('percentage',), 42),
#  (('leadership',), 40),
#  (('contact',), 40),
#  (('guidance',), 40),
#  (('president',), 40),
#  (('mastercard',), 40),
#  (('illustrate',), 40),
#  (('held',), 40),
#  (('authority',), 40),
#  (('tracking',), 40),
#  (('movement',), 40),
#  (('european',), 40),
#  (('psd',), 40),
#  (('rely',), 40),
#  (('achieve',), 40),
#  (('addition',), 40),
#  (('enforcement',), 40),
#  (('free',), 40),
#  (('storage',), 40),
#  (('gap',), 40),
#  (('car',), 40),
#  (('created',), 40),
#  (('breach',), 40),
#  (('stickiness',), 40),
#  (('speed',), 40),
#  (('custom',), 40),
#  (('concept',), 40),
#  (('recipient',), 40),
#  (('historical',), 40),
#  (('generated',), 40),
#  (('aml',), 40),
#  (('submission',), 40),
#  (('exporter',), 40),
#  (('address',), 38),
#  (('perspective',), 38),
#  (('ongoing',), 38),
#  (('consulting',), 38),
#  (('visa',), 38),
#  (('michael',), 38),
#  (('cycle',), 38),
#  (('acquire',), 38),
#  (('longer',), 38),
#  (('fewer',), 38),
#  (('decline',), 38),
#  (('developing',), 38),
#  (('feature',), 38),
#  (('failure',), 38),
#  (('australia',), 38),
#  (('tailored',), 38),
#  (('generation',), 38),
#  (('fixed',), 38),
#  (('typically',), 38),
#  (('poor',), 38),
#  (('emerge',), 38),
#  (('considered',), 38),
#  (('facilitates',), 38),
#  (('dimension',), 38),
#  (('standardised',), 38),
#  (('affect',), 36),
#  (('strategic',), 36),
#  (('apple',), 36),
#  (('suite',), 36),
#  (('proliferation',), 36),
#  (('expansion',), 36),
#  (('findingscontext',), 36),
#  (('capture',), 36),
#  (('aggregate',), 36),
#  (('complexity',), 36),
#  (('background',), 36),
#  (('efindings',), 36),
#  (('majority',), 36),
#  (('incentive',), 36),
#  (('erosion',), 36),
#  (('age',), 36),
#  (('traditionally',), 36),
#  (('differentiated',), 36),
#  (('volatility',), 36),
#  (('issued',), 36),
#  (('aspect',), 36),
#  (('express',), 36),
#  (('behalf',), 36),
#  (('credential',), 36),
#  (('assurance',), 36),
#  (('decreased',), 36),
#  (('cluster',), 36),
#  (('personalised',), 36),
#  (('pledged',), 36),
#  (('absorption',), 36),
#  (('depiction',), 36),
#  (('cast',), 36),
#  (('forward',), 34),
#  (('publication',), 34),
#  (('rob',), 34),
#  (('oversight',), 34),
#  (('shape',), 34),
#  (('decade',), 34),
#  (('represents',), 34),
#  (('clear',), 34),
#  (('fully',), 34),
#  (('adapt',), 34),
#  (('acquisition',), 34),
#  (('identified',), 34),
#  (('facing',), 34),
#  (('shopping',), 34),
#  (('scope',), 34),
#  (('sustainable',), 34),
#  (('confirmation',), 34),
#  (('participating',), 34),
#  (('variety',), 34),
#  (('suited',), 34),
#  (('takeaway',), 34),
#  (('acceptance',), 34),
#  (('average',), 34),
#  (('generate',), 34),
#  (('category',), 34),
#  (('fit',), 34),
#  (('html',), 34),
#  (('nature',), 34),
#  (('onboarding',), 34),
#  (('safe',), 34),
#  (('deal',), 34),
#  (('proven',), 34),
#  (('verify',), 34),
#  (('funded',), 34),
#  (('rating',), 34),
#  (('reduction',), 34),
#  (('crowd',), 34),
#  (('discovery',), 34),
#  (('explored',), 34),
#  (('bill',), 34),
#  (('filing',), 34),
#  (('intensive',), 34),
#  (('eliminate',), 34),
#  (('accrue',), 34),
#  (('empowerment',), 34),
#  (('specialised',), 34),
#  (('ass',), 34),
#  (('alignment',), 34),
#  (('adviser',), 32),
#  (('dttl',), 32),
#  (('deutsche',), 32),
#  (('paul',), 32),
#  (('annual',), 32),
#  (('outlook',), 32),
#  (('note',), 32),
#  (('dominant',), 32),
#  (('union',), 32),
#  (('profitable',), 32),
#  (('pre',), 32),
#  (('distribute',), 32),
#  (('competing',), 32),
#  (('offered',), 32),
#  (('stress',), 32),
#  (('simple',), 32),
#  (('regional',), 32),
#  (('uncertain',), 32),
#  (('asia',), 32),
#  (('challenger',), 32),
#  (('exists',), 32),
#  (('issuing',), 32),
#  (('cheaper',), 32),
#  (('differentiator',), 32),
#  (('economics',), 32),
#  (('branch',), 32),
#  (('learning',), 32),
#  (('analyse',), 32),
#  (('mail',), 32),
#  (('managed',), 32),
#  (('reduces',), 32),
#  (('instrument',), 32),
#  (('gratitude',), 32),
#  (('andrew',), 32),
#  (('authenticate',), 32),
#  (('transact',), 32),
#  (('delivered',), 32),
#  (('disintermediation',), 32),
#  (('adjuster',), 32),
#  (('initiative',), 30),
#  (('weforum',), 30),
#  (('stanley',), 30),
#  (('america',), 30),
#  (('enter',), 30),
#  (('china',), 30),
#  (('switch',), 30),
#  (('workforce',), 30),
#  (('monetization',), 30),
#  (('externalization',), 30),
#  (('app',), 30),
#  (('stream',), 30),
#  (('frequently',), 30),
#  (('needed',), 30),
#  (('follow',), 30),
#  (('intelligence',), 30),
#  (('people',), 30),
#  (('requiring',), 30),
#  (('guide',), 30),
#  (('diverse',), 30),
#  (('europe',), 30),
#  (('bitcoin',), 30),
#  (('largest',), 30),
#  (('focusing',), 30),
#  (('flexibility',), 30),
#  (('convenience',), 30),
#  (('difficulty',), 30),
#  (('spending',), 30),
#  (('spread',), 30),
#  (('underserved',), 30),
#  (('auto',), 30),
#  (('communication',), 30),
#  (('newer',), 30),
#  (('layer',), 30),
#  (('minimum',), 30),
#  (('active',), 30),
#  (('consolidated',), 30),
#  (('valuation',), 30),
#  (('otc',), 30),
#  (('principal',), 30),
#  (('diversified',), 30),
#  (('inspection',), 30),
#  (('galaski',), 28),
#  (('david',), 28),
#  (('barclays',), 28),
#  (('define',), 28),
#  (('vice',), 28),
#  (('blackrock',), 28),
#  (('meeting',), 28),
#  (('consider',), 28),
#  (('transformative',), 28),
#  (('evolutionary',), 28),
#  (('broad',), 28),
#  (('phone',), 28),
#  (('short',), 28),
#  (('part',), 28),
#  (('geography',), 28),
#  (('rising',), 28),
#  (('owner',), 28),
#  (('competitor',), 28),
#  (('middle',), 28),
#  (('regulated',), 28),
#  (('vendor',), 28),
#  (('moving',), 28),
#  (('challenging',), 28),
#  (('led',), 28),
#  (('greatly',), 28),
#  (('circa',), 28),
#  (('differ',), 28),
#  (('mid',), 28),
#  (('border',), 28),
#  (('apis',), 28),
#  (('bet',), 28),
#  (('mutual',), 28),
#  (('accurately',), 28),
#  (('daily',), 28),
#  (('white',), 28),
#  (('maturity',), 28),
#  (('update',), 28),
#  (('replace',), 28),
#  (('fall',), 28),
#  (('diversification',), 28),
#  (('commission',), 28),
#  (('bloomberg',), 28),
#  (('averse',), 28),
#  (('giancarlo',), 28),
#  (('database',), 28),
#  (('contributed',), 28),
#  (('validation',), 28),
#  (('reliable',), 28),
#  (('costly',), 28),
#  (('prediction',), 28),
#  (('issuance',), 28),
#  (('fiat',), 28),
#  (('contingent',), 28),
#  (('invoice',), 28),
#  (('shipment',), 28),
#  (('steering',), 26),
#  (('committee',), 26),
#  (('ubs',), 26),
#  (('hsbc',), 26),
#  (('lloyd',), 26),
#  ...]

# %%
bigram_freq
# Out:
# {'financial institution': 682,
#  'economic forum': 536,
#  'financial service': 440,
#  'world economic': 380,
#  'digital identity': 322,
#  'identity system': 300,
#  'uncertainty statesintroduction': 294,
#  'statesintroduction conclusion': 286,
#  'smart contract': 270,
#  'real time': 258,
#  'finding uncertainty': 194,
#  'retrieved http': 188,
#  'case study': 168,
#  'investment management': 166,
#  'key uncertainty': 152,
#  'current state': 144,
#  'equity crowdfunding': 126,
#  'business model': 126,
#  'individual investor': 124,
#  'payment scheme': 120,
#  'third party': 118,
#  'service provider': 116,
#  'buyer seller': 112,
#  'distributed ledger': 112,
#  'wealth manager': 110,
#  'critical condition': 108,
#  'alternative lending': 108,
#  'capital raising': 108,
#  'future state': 100,
#  'traditional institution': 98,
#  'credit card': 94,
#  'key finding': 92,
#  'product service': 90,
#  'venture capital': 90,
#  'risk associated': 90,
#  'proxy statement': 90,
#  'financial product': 88,
#  'alternative funding': 88,
#  'investment opportunity': 88,
#  'coco bond': 88,
#  'market infrastructure': 86,
#  'implication scenario': 86,
#  'wealth management': 84,
#  'large tech': 84,
#  'post trade': 84,
#  'subject matter': 82,
#  'payment solution': 82,
#  'funding platform': 82,
#  'matter expert': 80,
#  'legal entity': 80,
#  'project team': 78,
#  'digital banking': 78,
#  'dfindings uncertainty': 78,
#  'customer experience': 76,
#  'bank account': 76,
#  'money transfer': 76,
#  'low cost': 76,
#  'opportunity risk': 76,
#  'state process': 76,
#  'market participant': 74,
#  'traditional intermediary': 72,
#  'lending platform': 72,
#  'insurance product': 70,
#  'deposit lending': 70,
#  'investor investor': 70,
#  'alternative payment': 68,
#  'marketplace lender': 68,
#  'capital market': 64,
#  'market provisioning': 64,
#  'narrative summary': 64,
#  'summary impact': 64,
#  'supporting evidence': 62,
#  'traditional payment': 62,
#  'high risk': 62,
#  'data source': 62,
#  'associated scenario': 62,
#  'future financial': 60,
#  'mobile payment': 60,
#  'quantitative evidence': 60,
#  'pain point': 60,
#  'net worth': 60,
#  'high net': 60,
#  'condition scenario': 60,
#  'scenario implication': 60,
#  'incumbent ecosystem': 60,
#  'lead arranger': 60,
#  'trading strategy': 58,
#  'market share': 56,
#  'risk profile': 56,
#  'correspondent bank': 56,
#  'identity transaction': 54,
#  'connected device': 54,
#  'mass affluent': 54,
#  'scenario customer': 54,
#  'customer incumbent': 54,
#  'trade finance': 54,
#  'tech firm': 52,
#  'customer base': 52,
#  'global payment': 52,
#  'user attribute': 52,
#  'smarter faster': 52,
#  'process externalisation': 52,
#  'deep dive': 50,
#  'life insurance': 50,
#  'crowdfunding platform': 50,
#  'ledger technology': 50,
#  'faster machine': 50,
#  'syndicated loan': 50,
#  'financial system': 48,
#  'customer relationship': 48,
#  'asset class': 48,
#  'alternative platform': 48,
#  'capital ratio': 48,
#  'innovation financial': 46,
#  'implication regulator': 46,
#  'robo advisor': 46,
#  'condition early': 46,
#  'early sign': 46,
#  'traditional wealth': 46,
#  'low risk': 46,
#  'deloitte canada': 46,
#  'key implication': 46,
#  'transfer operator': 46,
#  'identity solution': 44,
#  'disruptive innovation': 44,
#  'lower cost': 44,
#  'implication incumbent': 44,
#  'shifting customer': 44,
#  'payment network': 44,
#  'digital channel': 44,
#  'traditional financial': 44,
#  'emerging market': 44,
#  'state paint': 44,
#  'retail bank': 44,
#  'seed stage': 44,
#  'asset rehypothecation': 44,
#  'implication remaining': 44,
#  'remaining question': 44,
#  'jesse mcwaters': 42,
#  'thomson reuters': 42,
#  'managing director': 42,
#  'approach key': 42,
#  'incumbent institution': 42,
#  'institutional investor': 42,
#  'implication financial': 42,
#  'sign finding': 42,
#  'state finding': 42,
#  'claim processing': 42,
#  'identity network': 42,
#  'investment bank': 42,
#  'export bank': 42,
#  'financial infrastructure': 40,
#  'customer data': 40,
#  'executive summary': 40,
#  'identity provider': 40,
#  'relying party': 40,
#  'counterparty risk': 40,
#  'decentralised traditional': 40,
#  'algorithmic trading': 40,
#  'insurance policy': 40,
#  'peer based': 40,
#  'state pain': 40,
#  'process description': 40,
#  'import bank': 40,
#  'bank money': 40,
#  'implication customer': 38,
#  'financial ecosystem': 38,
#  'uncertainty future': 38,
#  'interest rate': 38,
#  'alternative model': 38,
#  'private equity': 38,
#  'service delivery': 38,
#  'key characteristic': 38,
#  'connection platform': 38,
#  'proxy voting': 38,
#  'custodian bank': 38,
#  'global financial': 36,
#  'long term': 36,
#  'key findingscontext': 36,
#  'findingscontext approach': 36,
#  'economy scale': 36,
#  'risk management': 36,
#  'potential state': 36,
#  'efindings uncertainty': 36,
#  'hedge fund': 36,
#  'demand supply': 36,
#  'physical identity': 36,
#  'transaction history': 36,
#  'case deep': 36,
#  'loan absorption': 36,
#  'process depiction': 36,
#  'state benefit': 36,
#  'challenge challenge': 36,
#  'service industry': 34,
#  'chief executive': 34,
#  'user experience': 34,
#  'competitive landscape': 34,
#  'customer trust': 34,
#  'key takeaway': 34,
#  'customer benefit': 34,
#  'connected insurance': 34,
#  'customer loyalty': 34,
#  'gain access': 34,
#  'party data': 34,
#  'trading platform': 34,
#  'user group': 34,
#  'distributed identity': 34,
#  'model lending': 34,
#  'founder ceo': 34,
#  'payment cashless': 34,
#  'lending alternative': 34,
#  'letter credit': 34,
#  'depiction world': 34,
#  'rehypothecation percentage': 34,
#  'custodian custodian': 34,
#  'head financial': 32,
#  'financial crisis': 32,
#  'role financial': 32,
#  'customer expectation': 32,
#  'competitive advantage': 32,
#  'online mobile': 32,
#  'alternative lender': 32,
#  'faster payment': 32,
#  'insurance company': 32,
#  'decision making': 32,
#  'playing field': 32,
#  'infrastructure provider': 32,
#  'express gratitude': 32,
#  'attribute exchange': 32,
#  'complete transaction': 32,
#  'benefit accrue': 32,
#  'high frequency': 32,
#  'alternative scheme': 32,
#  'automated compliance': 32,
#  'equity post': 32,
#  'loss adjuster': 32,
#  'weforum org': 30,
#  'executive officer': 30,
#  'global head': 30,
#  'morgan stanley': 30,
#  'director head': 30,
#  'customer segment': 30,
#  'finding quantitative': 30,
#  'sharing economy': 30,
#  'challenger bank': 30,
#  'increased competition': 30,
#  'study quantitative': 30,
#  'niche market': 30,
#  'manual process': 30,
#  'technology provider': 30,
#  'public private': 30,
#  'private sector': 30,
#  'empowerment individual': 30,
#  'real life': 30,
#  'life event': 30,
#  'payment decentralised': 30,
#  'core capability': 30,
#  'stress test': 30,
#  'rob galaski': 28,
#  'service customer': 28,
#  'distribution channel': 28,
#  'asset management': 28,
#  'data customer': 28,
#  'payment system': 28,
#  'state critical': 28,
#  'state three': 28,
#  'insurance chain': 28,
#  'customer preference': 28,
#  'market competitive': 28,
#  'access data': 28,
#  'robo advisory': 28,
#  'process execution': 28,
#  'large number': 28,
#  'risk high': 28,
#  'team express': 28,
#  'entity asset': 28,
#  'implication fis': 28,
#  'management empowerment': 28,
#  'today future': 28,
#  'view market': 28,
#  'disaggregation chain': 28,
#  'increasing level': 28,
#  'level connectivity': 28,
#  'smaller institution': 28,
#  'customer channel': 28,
#  'channel preference': 28,
#  'stage company': 28,
#  'large small': 28,
#  'member member': 28,
#  'pledged member': 28,
#  'working group': 26,
#  'deloitte consulting': 26,
#  'consulting llp': 26,
#  'united state': 26,
#  'member firm': 26,
#  'evolutionary path': 26,
#  'apple pay': 26,
#  'institution ability': 26,
#  'middle office': 26,
#  'gain market': 26,
#  'open platform': 26,
#  'asset manager': 26,
#  'allow customer': 26,
#  'shift focus': 26,
#  'alternative currency': 26,
#  'payment ecosystem': 26,
#  'customer risk': 26,
#  'platform provide': 26,
#  'lending model': 26,
#  'small medium': 26,
#  'big data': 26,
#  'external service': 26,
#  'risk averse': 26,
#  'time settlement': 26,
#  'expert contributed': 26,
#  'alphabetical order': 26,
#  'user consent': 26,
#  'potential future': 26,
#  'traditional player': 26,
#  'insurance disaggregation': 26,
#  'frequency trading': 26,
#  'insurance increasing': 26,
#  'business process': 26,
#  'raising alternative': 26,
#  'principal interest': 26,
#  'market large': 26,
#  'regulatory agency': 26,
#  'management process': 26,
#  'provisioning connecting': 26,
#  'connecting buyer': 26,
#  'contingent convertible': 26,
#  'bank investor': 26,
#  'forum current': 26,
#  'public sector': 24,
#  'professional service': 24,
#  'head strategy': 24,
#  'payment innovation': 24,
#  'wide range': 24,
#  'customer bank': 24,
#  'product manufacturing': 24,
#  'control customer': 24,
#  'regulatory environment': 24,
#  'conclusion case': 24,
#  'alternative rail': 24,
#  'card issuer': 24,
#  'insurance finding': 24,
#  'insurance industry': 24,
#  'commercial line': 24,
#  'traditional bank': 24,
#  'cost product': 24,
#  'move upstream': 24,
#  'human error': 24,
#  'management industry': 24,
#  'product offering': 24,
#  'secondary market': 24,
#  'buy side': 24,
#  'giancarlo bruno': 24,
#  'regulatory compliance': 24,
#  'access service': 24,
#  'financial transaction': 24,
#  'dlt potential': 24,
#  'complete view': 24,
#  'provisioning smarter': 24,
#  'disruptive trend': 24,
#  'lending shifting': 24,
#  'characteristic future': 24,
#  'potential outcome': 24,
#  'key question': 24,
#  'scenario realised': 24,
#  'summary context': 24,
#  'customer merchantspayment': 24,
#  'merchantspayment solution': 24,
#  'settlement time': 24,
#  'process technology': 24,
#  'risk seeking': 24,
#  'risk borrower': 24,
#  'mass investor': 24,
#  'investment expert': 24,
#  'convertible coco': 24,
#  'stakeholder alignment': 24,
#  'financial agreement': 24,
#  'compliance activity': 24,
#  'member pledged': 24,
#  'cast vote': 24,
#  'percentage rehypothecation': 24,
#  'steering committee': 22,
#  'forum project': 22,
#  'deloitte touche': 22,
#  'private company': 22,
#  'corporate strategy': 22,
#  'deutsche bank': 22,
#  'property casualty': 22,
#  'business development': 22,
#  'data set': 22,
#  'reduce cost': 22,
#  'barrier entry': 22,
#  'competitive pressure': 22,
#  'management service': 22,
#  'card based': 22,
#  'payment finding': 22,
#  'point sale': 22,
#  'initiate payment': 22,
#  'cross border': 22,
#  'solution bank': 22,
#  'traditional scheme': 22,
#  'balance sheet': 22,
#  'personal insurance': 22,
#  'full service': 22,
#  'alternative adjudication': 22,
#  'financial platform': 22,
#  'machine learning': 22,
#  'funding cost': 22,
#  'financial data': 22,
#  'track record': 22,
#  'fixed income': 22,
#  'equity investment': 22,
#  'trade process': 22,
#  'technology platform': 22,
#  'traditional provider': 22,
#  'contributed valuable': 22,
#  'valuable perspective': 22,
#  'perspective interview': 22,
#  'attribute collection': 22,
#  'identity management': 22,
#  'identity service': 22,
#  'tax filing': 22,
#  'access trusted': 22,
#  'natural identity': 22,
#  'idp rps': 22,
#  'dimension choice': 22,
#  'digital wallet': 22,
#  'application dlt': 22,
#  'reducing time': 22,
#  'role traditional': 22,
#  'key disruptive': 22,
#  'default card': 22,
#  'funding option': 22,
#  'context innovation': 22,
#  'scenario illustrate': 22,
#  'illustrate potential': 22,
#  'outcome generated': 22,
#  'generated innovation': 22,
#  'innovation discussed': 22,
#  'discussed topic': 22,
#  'topic response': 22,
#  'response key': 22,
#  'question meant': 22,
#  'meant future': 22,
#  'future prediction': 22,
#  'prediction scenario': 22,
#  'scenario illustration': 22,
#  'illustration aspect': 22,
#  'aspect potential': 22,
#  'future meant': 22,
#  'meant represent': 22,
#  'represent complete': 22,
#  'landscape case': 22,
#  'case scenario': 22,
#  'realised time': 22,
#  'question scenario': 22,
#  'safe bet': 22,
#  'bet implication': 22,
#  'fiat currency': 22,
#  'alternative provider': 22,
#  'personal data': 22,
#  'large institution': 22,
#  'asset product': 22,
#  'benefit world': 22,
#  'sender beneficiary': 22,
#  'vice president': 20,
#  'service project': 20,
#  'regulator incumbent': 20,
#  'transformative potential': 20,
#  'finding key': 20,
#  'profit pool': 20,
#  'fintechs regulator': 20,
#  'implication fintechs': 20,
#  'united kingdom': 20,
#  'customer demand': 20,
#  'customer engagement': 20,
#  'trade execution': 20,
#  'participant role': 20,
#  'key ecosystem': 20,
#  'ecosystem stakeholder': 20,
#  'key trend': 20,
#  'future payment': 20,
#  'customer behaviour': 20,
#  'scheme traditional': 20,
#  'critical mass': 20,
#  'customer acquisition': 20,
#  'financial firm': 20,
#  'lending finding': 20,
#  'source data': 20,
#  'online lender': 20,
#  'medium sized': 20,
#  'investment advice': 20,
#  'early stage': 20,
#  'angel investor': 20,
#  'market platform': 20,
#  'financial return': 20,
#  'large scale': 20,
#  'potential impact': 20,
#  'allow fis': 20,
#  'authenticate user': 20,
#  'single entity': 20,
#  'compliance process': 20,
#  'user identity': 20,
#  'attribute user': 20,
#  'system designed': 20,
#  'authentication system': 20,
#  'centralized identity': 20,
#  'population registry': 20,
#  'system built': 20,
#  'digital attribute': 20,
#  'cluster innovation': 20,
#  'primary account': 20,
#  'individual risk': 20,
#  'averse risk': 20,
#  'niche provider': 20,
#  'worth institutional': 20,
#  'series mid': 20,
#  'affluent market': 20,
#  'market making': 20,
#  'market connection': 20,
#  'regulatory governance': 20,
#  'summary outlook': 20,
#  'unanswered question': 20,
#  'importer exporter': 20,
#  'point time': 20,
#  'trigger option': 20,
#  'potential financial': 18,
#  'advice service': 18,
#  'group head': 18,
#  'retail banking': 18,
#  'identity protocol': 18,
#  'industry leader': 18,
#  'data monetization': 18,
#  'cost effective': 18,
#  'product manufacturer': 18,
#  'small business': 18,
#  'platform allow': 18,
#  'legacy system': 18,
#  'artificial intelligence': 18,
#  'bank america': 18,
#  'cloud based': 18,
#  'conclusion key': 18,
#  'market incumbent': 18,
#  'mobile wallet': 18,
#  'insurer ability': 18,
#  'life insurer': 18,
#  'risk capital': 18,
#  'insurance state': 18,
#  'incumbent bank': 18,
#  'regulator bank': 18,
#  'focus niche': 18,
#  'data breach': 18,
#  'thin file': 18,
#  'evidence key': 18,
#  'capability provider': 18,
#  'external provider': 18,
#  'office function': 18,
#  'data driven': 18,
#  'retail investor': 18,
#  'small large': 18,
#  'crowdfunding finding': 18,
#  'platform traditional': 18,
#  'capital investment': 18,
#  'access capital': 18,
#  'regulatory change': 18,
#  'infrastructure finding': 18,
#  'seller intermediary': 18,
#  'data provider': 18,
#  'life cycle': 18,
#  'senior director': 18,
#  'gratitude subject': 18,
#  'central bank': 18,
#  'best suited': 18,
#  'provide identity': 18,
#  'authorization attribute': 18,
#  'authentication attribute': 18,
#  'user control': 18,
#  'system user': 18,
#  'attribute transferred': 18,
#  'secondary dimension': 18,
#  'transparent view': 18,
#  'merchant payment': 18,
#  'mobile money': 18,
#  'institution financial': 18,
#  'payment market': 18,
#  'standardised platform': 18,
#  'fund fund': 18,
#  'key opportunity': 18,
#  'account provider': 18,
#  'sender recipient': 18,
#  'sender bank': 18,
#  'cross sell': 18,
#  'insurance model': 18,
#  'opportunity exist': 18,
#  'risk appetite': 18,
#  'saver borrower': 18,
#  'virtual channel': 18,
#  'automated investment': 18,
#  'raising platform': 18,
#  'capital private': 18,
#  'intermediating institution': 18,
#  'mid market': 18,
#  'opportunity local': 18,
#  'return investment': 18,
#  'based funding': 18,
#  'externalisation provider': 18,
#  'newer smaller': 18,
#  'algorithmic trader': 18,
#  'case highlight': 18,
#  'participant world': 18,
#  'beneficiary bank': 18,
#  'condition implementation': 18,
#  'financial detail': 18,
#  'time stress': 18,
#  'investment record': 18,
#  'stored dlt': 18,
#  'state background': 18,
#  'background key': 18,
#  'stakeholder overview': 18,
#  'introduction world': 18,
#  'role description': 18,
#  'key market': 18,
#  'condition world': 18,
#  'alignment technology': 18,
#  'technology regulatory': 18,
#  'governance critical': 18,
#  'condition category': 18,
#  'outlook key': 18,
#  'takeaway unanswered': 18,
#  'conclusion world': 18,
#  'syndicate member': 18,
#  'bank regulator': 18,
#  'online mail': 18,
#  'safekeeping account': 18,
#  'entity dttl': 16,
#  'dttl member': 16,
#  'professional advice': 16,
#  'mcwaters weforum': 16,
#  'thought leadership': 16,
#  'banking group': 16,
#  'mcwaters project': 16,
#  'project lead': 16,
#  'context approach': 16,
#  'contact detail': 16,
#  'key stakeholder': 16,
#  'blueprint digital': 16,
#  'broader financial': 16,
#  'innovator subject': 16,
#  'core competency': 16,
#  'loan origination': 16,
#  'uncertainty fintechs': 16,
#  'regulator implication': 16,
#  'product distributor': 16,
#  'advisory service': 16,
#  'future market': 16,
#  'distribution platform': 16,
#  'aggregation platform': 16,
#  'incumbent implication': 16,
#  'digital experience': 16,
#  'data collection': 16,
#  'advanced analytics': 16,
#  'best execution': 16,
#  'clearing house': 16,
#  'path forward': 16,
#  'takeaway financial': 16,
#  'major force': 16,
#  'low fee': 16,
#  'revenue stream': 16,
#  'customer implication': 16,
#  'card usage': 16,
#  'product customer': 16,
#  'meet customer': 16,
#  'business insider': 16,
#  'core business': 16,
#  'service product': 16,
#  'change role': 16,
#  'risk market': 16,
#  'based insurance': 16,
#  'personal line': 16,
#  'risk assessment': 16,
#  'virtual bank': 16,
#  'technology company': 16,
#  'banking finding': 16,
#  'party organization': 16,
#  'curated platform': 16,
#  'level playing': 16,
#  'service user': 16,
#  'high quality': 16,
#  'customer stickiness': 16,
#  'management finding': 16,
#  'market condition': 16,
#  'stage venture': 16,
#  'increased access': 16,
#  'platform grow': 16,
#  'deloitte rob': 16,
#  'support deloitte': 16,
#  'digital asset': 16,
#  'asset holding': 16,
#  'service community': 16,
#  'multi stakeholder': 16,
#  'addition project': 16,
#  'identity challenge': 16,
#  'global identity': 16,
#  'delivery authorization': 16,
#  'exchange authentication': 16,
#  'collection standard': 16,
#  'legal regulatory': 16,
#  'transaction require': 16,
#  'governance body': 16,
#  'act idp': 16,
#  'transferred idp': 16,
#  'identity offer': 16,
#  'transfer attribute': 16,
#  'online service': 16,
#  'sector solution': 16,
#  'version truth': 16,
#  'identity help': 16,
#  'risk customer': 16,
#  'ecosystem increased': 16,
#  'institution leverage': 16,
#  'payment settlement': 16,
#  'saving payment': 16,
#  'service function': 16,
#  'improve efficiency': 16,
#  'technology player': 16,
#  'cost saving': 16,
#  'claim servicing': 16,
#  'institution alternative': 16,
#  'interest payment': 16,
#  'clearing settlement': 16,
#  'larger company': 16,
#  'investor high': 16,
#  'seed series': 16,
#  'field newer': 16,
#  'larger institution': 16,
#  'financial asset': 16,
#  'buyer intermediary': 16,
#  'large large': 16,
#  'service infrastructure': 16,
#  'dlt provide': 16,
#  'highlight key': 16,
#  'operational risk': 16,
#  'diligence underwriting': 16,
#  'absorption activated': 16,
#  'adjuster claim': 16,
#  'category summary': 16,
#  'core entity': 16,
#  'custom country': 16,
#  'verified good': 16,
#  'bill lading': 16,
#  'audit report': 16,
#  'statement investor': 16,
#  'bank collateral': 16,
#  'equity trade': 16,
#  'trade detail': 16,
#  'deloitte detailed': 14,
#  'detailed description': 14,
#  'chief operating': 14,
#  'operating officer': 14,
#  'strategy business': 14,
#  'chief technology': 14,
#  'capital partner': 14,
#  'service ecosystem': 14,
#  'model financial': 14,
#  'high level': 14,
#  'leader innovator': 14,
#  'cost high': 14,
#  'payment rail': 14,
#  'service financial': 14,
#  'institution increasingly': 14,
#  'multiple source': 14,
#  'customer facing': 14,
#  'regulator monitor': 14,
#  'saving account': 14,
#  'european union': 14,
#  'ownership customer': 14,
#  'product distribution': 14,
#  'pre existing': 14,
#  'role human': 14,
#  'financial market': 14,
#  'key innovation': 14,
#  'greatly evolved': 14,
#  'evolved year': 14,
#  'year examines': 14,
#  'examines key': 14,
#  'trend shaping': 14,
#  'shaping industry': 14,
#  'industry uncertain': 14,
#  'uncertain path': 14,
#  'introduction finding': 14,
#  'conclusion half': 14,
#  'half decade': 14,
#  'payment landscape': 14,
#  'circa major': 14,
#  'force impacting': 14,
#  'circa big': 14,
#  'big uncertainty': 14,
#  'disruption occur': 14,
#  'disruption occurred': 14,
#  'mobile channel': 14,
#  'overview finding': 14,
#  'online payment': 14,
#  'short term': 14,
#  'directly bank': 14,
#  'wall street': 14,
#  'payment card': 14,
#  'emerged resolution': 14,
#  'resolution key': 14,
#  'uncertainty paint': 14,
#  'diverging picture': 14,
#  'picture future': 14,
#  'know uncertainty': 14,
#  'depending key': 14,
#  'uncertainty resolved': 14,
#  'resolved potential': 14,
#  'state evolutionary': 14,
#  'path implication': 14,
#  'implication firm': 14,
#  'second state': 14,
#  'third state': 14,
#  'data sharing': 14,
#  'three critical': 14,
#  'three finding': 14,
#  'forbes retrieved': 14,
#  'http forbes': 14,
#  'forbes site': 14,
#  'reference finding': 14,
#  'traditional product': 14,
#  'product design': 14,
#  'size fit': 14,
#  'market traditional': 14,
#  'term product': 14,
#  'improve customer': 14,
#  'benefit digital': 14,
#  'provide customer': 14,
#  'banking platform': 14,
#  'development digital': 14,
#  'allows user': 14,
#  'institution digital': 14,
#  'margin pressure': 14,
#  'based product': 14,
#  'compete directly': 14,
#  'platform focus': 14,
#  'platform emerging': 14,
#  'account receivable': 14,
#  'loan funded': 14,
#  'acquisition cost': 14,
#  'sophisticated capability': 14,
#  'risk lending': 14,
#  'customer financial': 14,
#  'charles schwab': 14,
#  'access investment': 14,
#  'casey quirk': 14,
#  'access sophisticated': 14,
#  'cash flow': 14,
#  'risk investment': 14,
#  'raise capital': 14,
#  'capital firm': 14,
#  'technology process': 14,
#  'risk investor': 14,
#  'investor regulator': 14,
#  'investor gain': 14,
#  'sell side': 14,
#  'joint venture': 14,
#  'revenue growth': 14,
#  'currently explored': 14,
#  'bruno senior': 14,
#  'acknowledgement list': 14,
#  'interview workshop': 14,
#  'workshop alphabetical': 14,
#  'identity critical': 14,
#  'technology solution': 14,
#  'landscape digital': 14,
#  'private service': 14,
#  'forum key': 14,
#  'government service': 14,
#  'understanding customer': 14,
#  'individual identity': 14,
#  'transaction counterparties': 14,
#  'view customer': 14,
#  'institution opportunity': 14,
#  'improved compliance': 14,
#  'support system': 14,
#  'required transaction': 14,
#  'transaction process': 14,
#  'transfer money': 14,
#  'user access': 14,
#  'access user': 14,
#  'single view': 14,
#  'single version': 14,
#  'implementation digital': 14,
#  'risk liability': 14,
#  'improved product': 14,
#  'customer deliver': 14,
#  'access financial': 14,
#  'traditional lender': 14,
#  'function financial': 14,
#  'provider financial': 14,
#  'customer gain': 14,
#  'trading activity': 14,
#  'activity automated': 14,
#  'share wallet': 14,
#  'flow money': 14,
#  'card customer': 14,
#  'retail financial': 14,
#  'institution facilitate': 14,
#  'saving lending': 14,
#  'scenario incumbent': 14,
#  'insurer insurer': 14,
#  'external party': 14,
#  'data insurer': 14,
#  'renewalbinding party': 14,
#  'behavioural data': 14,
#  'cross subsidisation': 14,
#  'platform alternative': 14,
#  'borrower lender': 14,
#  'institutional seed': 14,
#  'large alternative': 14,
#  'investment manager': 14,
#  'core process': 14,
#  'market maker': 14,
#  'smaller intermediary': 14,
#  'intermediary buyer': 14,
#  'intermediary seller': 14,
#  'required perform': 14,
#  'regulated entity': 14,
#  'dlt transformative': 14,
#  'bank correspondent': 14,
#  'local clearing': 14,
#  'clearing network': 14,
#  'utilizing dlt': 14,
#  'inspection company': 14,
#  'resource required': 14,
#  'party intermediary': 14,
#  'regulator supporting': 14,
#  'contract smart': 14,
#  'claim submission': 14,
#  'report loss': 14,
#  'request additional': 14,
#  'claim agent': 14,
#  'point world': 14,
#  'proof concept': 14,
#  'time intensive': 14,
#  'activity executed': 14,
#  'stored distributed': 14,
#  'bank export': 14,
#  'initiate shipment': 14,
#  'independent audit': 14,
#  'regulatory limit': 14,
#  'cash equity': 14,
#  'trade confirmation': 14,
#  'service series': 12,
#  'forum financial': 12,
#  'project steering': 12,
#  'deloitte network': 12,
#  'provide service': 12,
#  'decision action': 12,
#  'action affect': 12,
#  'affect business': 12,
#  'lead author': 12,
#  'leader global': 12,
#  'lloyd banking': 12,
#  'robert palatnick': 12,
#  'cvc capital': 12,
#  'julius baer': 12,
#  'huw van': 12,
#  'van steenis': 12,
#  'service economic': 12,
#  'sector deep': 12,
#  'key uncertaintiescontext': 12,
#  'uncertaintiescontext approach': 12,
#  'large technology': 12,
#  'incumbent financial': 12,
#  'rail alternative': 12,
#  'cost base': 12,
#  'platform offer': 12,
#  'time financial': 12,
#  'process automation': 12,
#  'data flow': 12,
#  'systemic risk': 12,
#  'control data': 12,
#  'data aggregation': 12,
#  'market data': 12,
#  'fintechs key': 12,
#  'offer customer': 12,
#  'mobile banking': 12,
#  'time data': 12,
#  'based data': 12,
#  'service implication': 12,
#  'single point': 12,
#  'customer platform': 12,
#  'experience customer': 12,
#  'regulatory framework': 12,
#  'financial time': 12,
#  'time retrieved': 12,
#  'reading guide': 12,
#  ...}

# %%
#change to directory
word_freq = ngram_to_dict(word_freq)
bigram_freq = ngram_to_dict(bigram_freq)
#trigram_freq = ngram_to_dict(trigram_freq)
#ngramFrequency = ngram_to_dict(ngram_freq)

# %%
word_dict = {}
bigram_dict = {}
trigram_dict = {}

# %%
#Take output into text format
import sys
sys.stdout = open('bigram_.txt','wt',encoding='utf-8')
print(bigram_freq)

# %%
#Convert list into dataframe
import pandas as pd

dfObj = pd.DataFrame(list(bbigram_freq.items()),columns=['bigram_Words', 'count'])

# %%
#Convert dataframe into csv file
dfObj.to_csv("output.csv", encoding='utf-8', index=False)
