# %%
#import necessary package
import pandas as pd
import featuretools as ft

# %%
df = pd.read_csv("cleanedloans.csv",header=0,encoding='utf-8')

# %%
# Make an entityset and add the entity
es = ft.EntitySet(id = 'data')
es.entity_from_dataframe(entity_id = 'data', dataframe = df, 
                         make_index = True, index = 'index')
# Out:
# Entityset: data
#   Entities:
#     data [Rows: 576839, Columns: 60]
#   Relationships:
#     No relationships

# %%
# Run deep feature synthesis with transformation primitives
feature_matrix, feature_defs = ft.dfs(entityset = es, target_entity = 'data',
                                      trans_primitives = ['absolute','percentile'])

feature_matrix.head()
# Out:
#        member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# index
# 0       12000897    27050.0      27050.0          27050.0     10.99
# 1       12011200     9750.0       9750.0           9750.0     13.98
# 2        1319523    12000.0      12000.0          12000.0      6.62
# 3       12011167    15000.0      15000.0          15000.0      8.90
# 4       11971241    12000.0      12000.0          12000.0     11.99
#
#        installment  grade sub_grade  emp_length  annual_inc  \
# index
# 0           885.46      2        B2          10     55000.0
# 1           333.14      3        C1           1     26000.0
# 2           368.45      1        A2          10    105000.0
# 3           476.30      1        A5           2     63000.0
# 4           398.52      2        B3          10    130000.0
#
#                        ...                    \
# index                  ...
# 0                      ...
# 1                      ...
# 2                      ...
# 3                      ...
# 4                      ...
#
#       PERCENTILE(ABSOLUTE(purpose_major_purchase))  \
# index
# 0                                         0.491554
# 1                                         0.491554
# 2                                         0.491554
# 3                                         0.491554
# 4                                         0.491554
#
#       PERCENTILE(ABSOLUTE(purpose_medical))  \
# index
# 0                                  0.495698
# 1                                  0.495698
# 2                                  0.495698
# 3                                  0.495698
# 4                                  0.495698
#
#        PERCENTILE(ABSOLUTE(purpose_moving))  \
# index
# 0                                  0.497389
# 1                                  0.497389
# 2                                  0.497389
# 3                                  0.497389
# 4                                  0.497389
#
#        PERCENTILE(ABSOLUTE(purpose_other))  \
# index
# 0                                 0.478437
# 1                                 0.478437
# 2                                 0.478437
# 3                                 0.478437
# 4                                 0.478437
#
#        PERCENTILE(ABSOLUTE(purpose_renewable_energy))  \
# index
# 0                                            0.499763
# 1                                            0.499763
# 2                                            0.499763
# 3                                            0.499763
# 4                                            0.499763
#
#        PERCENTILE(ABSOLUTE(purpose_small_business))  \
# index
# 0                                          0.495729
# 1                                          0.495729
# 2                                          0.495729
# 3                                          0.495729
# 4                                          0.495729
#
#        PERCENTILE(ABSOLUTE(purpose_vacation))  \
# index
# 0                                    0.497582
# 1                                    0.497582
# 2                                    0.497582
# 3                                    0.497582
# 4                                    0.497582
#
#        PERCENTILE(ABSOLUTE(purpose_wedding))  \
# index
# 0                                   0.499769
# 1                                   0.499769
# 2                                   0.499769
# 3                                   0.499769
# 4                                   0.499769
#
#        PERCENTILE(ABSOLUTE(term_ 36 months))  \
# index
# 0                                   0.667762
# 1                                   0.667762
# 2                                   0.667762
# 3                                   0.667762
# 4                                   0.667762
#
#        PERCENTILE(ABSOLUTE(term_ 60 months))
# index
# 0                                    0.33224
# 1                                    0.33224
# 2                                    0.33224
# 3                                    0.33224
# 4                                    0.33224
#
# [5 rows x 213 columns]

# %%
feature_matrix.to_csv('featuretool.csv')
